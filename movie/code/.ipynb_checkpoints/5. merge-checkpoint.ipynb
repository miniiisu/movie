# %% [markdown]
# # 5. 데이터 전처리
# ### 1) kobis와 네이버 영화에서 수집한 데이터 중
# ### kobis 영화코드와 네이버 영화코드를 단일화 작업 후
# ### 분석에 필요한 데이터만 추출

# %%
import pandas as pd
import numpy as np

# %%
movie_info_path='/home/ubuntu/miniii_su/movie/'

df1 = pd.read_csv(movie_info_path+'data/movie_code_add_director.csv')
df2 = pd.read_csv(movie_info_path+'data/naver_boxoffice.csv')
df1 = df1.drop('Unnamed: 0',1)
df1 = df1.drop('Rate',1)
df3 = pd.merge(df1,df2,how='left',on='movieNm')

# %%
for i in range(len(df3['ntz_see_score'])):
    if(np.isnan(df3['ntz_see_score'][i])):
#         print(str(i)+" NaN")
        name = df3['movieNm'][i].replace(' ','')
#         print(name)
        for j in range(len(df2)):
            df2_name = df2['movieNm'][j].replace(' ','')
#             print(df2_name)
            if(df2_name[0:8] == name[0:8]):
                df3['naver_movieCd'][i] = df2['naver_movieCd'][j]
                df3['ntz_see_score'][i] = df2['ntz_see_score'][j]
                df3['spc_score'][i] = df2['spc_score'][j]
                df3['ntz_score'][i] = df2['ntz_score'][j]
                if(df2_name[0:6] == name[0:6]):
                    df3['naver_movieCd'][i] = df2['naver_movieCd'][j]
                    df3['ntz_see_score'][i] = df2['ntz_see_score'][j]
                    df3['spc_score'][i] = df2['spc_score'][j]
                    df3['ntz_score'][i] = df2['ntz_score'][j]
                    if(df2_name[0:4] == name[0:4]):     
                        df3['naver_movieCd'][i] = df2['naver_movieCd'][j]
                        df3['ntz_see_score'][i] = df2['ntz_see_score'][j]
                        df3['spc_score'][i] = df2['spc_score'][j]
                        df3['ntz_score'][i] = df2['ntz_score'][j]            
    elif(np.isnan(df3['naver_movieCd'][i])):
        df3['naver_movieCd'][i] = 0
        df3['ntz_see_score'][i] = 0
        df3['spc_score'][i] = 0
        df3['ntz_score'][i] = 0
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df3 = df3.dropna()
df3 = df3.reset_index(drop=True)
df3
# Out:
#       movieCd                          movieNm    director  naver_movieCd  \
# 0    20168323                               염력         연상호       153651.0
# 1    20176104                        그것만이 내 세상         최성현       158180.0
# 2    20178126                    인시디어스4: 라스트 키      애덤 로비텔       158647.0
# 3    20179985                               코코      리 언크리치       151728.0
# 4    20175054                    메이즈 러너: 데스 큐어        웨스 볼       149248.0
# 5    20178395                           12 솔져스     니콜라이 퓰시       168037.0
# 6    20170590                             1987         장준환       158191.0
# 7    20179228                              마야2     노엘 클리어리       172009.0
# 8    20179205                  조선명탐정: 흡혈괴마의 비밀         김석윤       165748.0
# 9    20178469                           올 더 머니      리들리 스콧       163842.0
# 10   19980074                             타이타닉     제임스 카메론        18847.0
# 11   20189901                            더 포리너       마틴 캠벨       165791.0
# 12   20178672                            패딩턴 2         폴 킹       146489.0
# 13   20170841                          리틀 포레스트         임순례       154449.0
# 14   20170561                            블랙 팬서     라이언 쿠글러       137326.0
# 15   20168250                            골든슬럼버         노동석       158112.0
# 16   20078561                     명탐정 코난:감벽의 관  야마모토 야스이치로        66725.0
# 17   20179462                           위대한 쇼맨    마이클 그레이시       106360.0
# 18   20164844                   불한당: 나쁜 놈들의 세상         변성현       154112.0
# 19   20177946                        월요일이 사라졌다     토미 위르콜라       118955.0
# 20   20180542                     50가지 그림자: 해방      제임스 폴리       154598.0
# 21   20173436                셰이프 오브 워터: 사랑의 모양   기예르모 델 토로       158626.0
# 22   20189882                          반딧불이 딘딘         등위봉       171767.0
# 23   20150969                               궁합         홍창표       141206.0
# 24   20179731                      나미야 잡화점의 기적     히로키 류이치       159862.0
# 25   20180341                           레드 스패로    프란시스 로렌스       151744.0
# 26   20189861                            더 포스트    스티븐 스필버그       159848.0
# 27   20189663                              게이트         신재호       172005.0
# 28   20170402                              강철비         양우석       155665.0
# 29   20174965                극장판 포켓몬스터 너로 정했다!    유야마 쿠니히코       165722.0
# ..        ...                              ...         ...            ...
# 274  20161141                     50가지 그림자: 심연      제임스 폴리       144081.0
# 275  20163580                           그레이트 월         장예모       126034.0
# 276  20167362                             더 큐어     고어 버빈스키       143372.0
# 277  20161366                           그래, 가족         마대윤       151192.0
# 278  20167906                           마이펫 오지  알베르토 로드리게즈       157500.0
# 279  20161723                            싱글라이더         이주영       146459.0
# 280  20156562                           루시드 드림         김준성       130713.0
# 281  20167922                            핵소 고지        멜 깁슨       142305.0
# 282  20161725                              마스터         조의석       145162.0
# 283  20163183                   로그 원: 스타워즈 스토리     가렛 에드워즈       136868.0
# 284  20162025                                씽      가스 제닝스       144938.0
# 285  20144641                              판도라         박정우       132933.0
# 286  20162727                        루돌프와 많이있어    유야마 쿠니히코       153951.0
# 287  20162183  포켓몬 더 무비 XY&Z 「볼케니온 : 기계왕국의 비밀」    유야마 쿠니히코       152265.0
# 288  20152371                     당신, 거기 있어줄래요         홍지영       145292.0
# 289  20165285         극장판 도라에몽: 신 진구의 버스 오브 재팬    야쿠와 신노스케       141675.0
# 290  19890291                    해리가 샐리를 만났을 때       롭 라이너        10250.0
# 291  20161763                      나, 다니엘 블레이크        켄 로치       150376.0
# 292  20163014                     7년-그들이 없는 언론         김진혁       146526.0
# 293  20161084                             패신저스       모튼 틸덤       116233.0
# 294  20150966                         사랑하기 때문에         주지홍       140010.0
# 295  20165153              눈의 여왕 3: 눈과 불의 마법대결   알렉세이 트시칠린       156675.0
# 296  20151181                              여교사         김태용       139673.0
# 297  20164421                          어쌔신 크리드      저스틴 커젤       118307.0
# 298  20168381                             얼라이드    로버트 저메키스       149777.0
# 299  20168324             반지의 제왕 : 반지원정대 (확장판)       피터 잭슨        31794.0
# 300  20168664             반지의 제왕 : 두개의 탑 (확장판)       피터 잭슨        31795.0
# 301  20163186                         단지 세상의 끝      자비에 돌란       137958.0
# 302  20168689             반지의 제왕 : 왕의 귀환 (확장판)       피터 잭슨        31796.0
# 303  20168366        바다 탐험대 옥토넛 시즌4: 바다 괴물 대소동      다라 오코넬       158266.0
#
#      ntz_see_score  spc_score  ntz_score
# 0             6.21       6.00       4.99
# 1             9.17       5.20       8.91
# 2             7.32       5.33       6.85
# 3             9.20       8.00       9.25
# 4             8.16       5.00       7.85
# 5             9.66       5.00       8.14
# 6             9.31       8.08       9.24
# 7             9.14       6.00       9.36
# 8             7.52       5.17       6.63
# 9             8.52       7.00       7.96
# 10            9.86       9.33       9.32
# 11            9.50       5.67       7.75
# 12            9.13       7.67       9.12
# 13            9.01       6.36       8.76
# 14            8.33       6.67       7.51
# 15            6.29       5.00       5.25
# 16            8.59       5.00       8.42
# 17            9.29       6.60       9.38
# 18            8.15       5.83       6.21
# 19            8.50       5.25       8.32
# 20            8.37       2.67       7.95
# 21            8.68       8.18       8.36
# 22            7.78       6.00       7.90
# 23            7.49       4.00       6.48
# 24            7.66       5.75       7.34
# 25            8.54       5.33       8.55
# 26            8.81       7.63       8.76
# 27            9.05       3.00       3.66
# 28            8.73       7.18       8.34
# 29            8.91       6.00       8.85
# ..             ...        ...        ...
# 274           7.77       2.25       7.42
# 275           7.92       4.50       6.44
# 276           7.33       6.20       7.25
# 277           9.26       4.50       8.33
# 278           8.08       0.00       8.24
# 279           8.01       5.90       8.23
# 280           8.06       3.00       5.86
# 281           9.19       6.00       9.20
# 282           8.65       5.77       8.10
# 283           8.34       7.16       8.45
# 284           8.99       6.71       8.96
# 285           8.78       5.92       8.30
# 286           8.73       6.38       8.80
# 287           8.74       0.00       8.75
# 288           8.80       5.44       8.69
# 289           8.95       0.00       9.04
# 290           7.75       8.50       8.91
# 291           9.28       8.40       9.26
# 292           9.48       6.00       8.51
# 293           8.03       5.50       7.95
# 294           8.39       6.00       8.03
# 295           8.34       0.00       8.57
# 296           7.31       6.78       6.61
# 297           7.29       5.67       7.10
# 298           8.58       6.50       8.86
# 299           0.00       0.00       9.28
# 300           0.00       0.00       9.34
# 301           7.66       6.90       7.46
# 302           0.00       0.00       9.37
# 303           8.30       0.00       8.27
#
# [304 rows x 7 columns]

# %%
df3.to_csv(movie_info_path+'data/naver_movie_all.csv',index=False)
